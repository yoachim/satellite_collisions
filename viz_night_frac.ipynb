# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

# %%
data = np.load('contam_fractions.npz')

# %%
data.keys()
# Out:
# ['result_fractions', 'result_mjds']

# %%
data['result_mjds']
# Out:
# array([[ 59853.98383827,  59853.99375621,  59854.00367416, ...,
#          59854.37447232,  59854.38438317,  59854.39429403],
#        [ 59854.98429059,  59854.99422842,  59855.00416625, ...,
#          59855.37353681,  59855.38346839,  59855.39339997],
#        [ 59855.98474832,  59855.99470679,  59856.00466525, ...,
#          59856.37260303,  59856.38255592,  59856.39250881],
#        ...,
#        [ 63510.98593453,  63510.99594961,  63511.00596469, ...,
#          63511.37019561,  63511.38020535,  63511.3902151 ],
#        [ 63511.98641477,  63511.99645322,  63512.00649167, ...,
#          63512.36926863,  63512.37930183,  63512.38933504],
#        [ 63512.98690094,  63512.99696349,  63513.00702604, ...,
#          63513.36834063,  63513.37839874,  63513.38845686]])

# %%
midnight= data['result_mjds'][:, 4]

# %%
mjds = (data['result_mjds'].T - data['result_mjds'][:,4])*24.

# %%
night = data['result_fractions'][:,-1]
night = np.tile(night,9).reshape(mjds.shape)

# %%
mjds.shape
# Out:
# (9, 3660)

# %%
mjds[:,0]
# Out:
# array([-4.92563938, -4.68760867, -4.44957796, -1.        ,  0.        ,
#         1.        ,  4.44957796,  4.68743841,  4.92529886])

# %%
data['result_fractions'].shape
# Out:
# (3660, 10)

# %%
plt.scatter(mjds.ravel(), night.ravel(), c=data['result_fractions'][:,:-1].T.ravel(), alpha=.2)
cb = plt.colorbar()
plt.xlabel('Time from midnight (hours)')
plt.ylabel('Night (days)')
cb.set_label('Fraction of fields with satellites in 30s')
plt.ylim([0,366])
# Out:
# (0, 366)
